# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import sys
import os
def dataread(input,write=False,writeData=None):
    file_type=input.split('.')[-1]
    if file_type == 'xlsx':
        file=pd.read_excel(input)
    elif file_type == 'txt':
        file=pd.read_csv(input,sep='\t')
    elif file_type == 'csv':
        file=pd.read_csv(input)
    return file

# %%
#HPO=pd.read_csv('DBHPO.csv')
#OMIM=pd.read_csv('DBOMIM.csv')

# %%
#OMIM_new=pd.read_csv('08_26_all_omim_phenotype_translation.csv')

# %%
##  uniq the omim datasate and add chinesed omim description in to colums, generate the format that we need 
#OMIM_ch=[]
#OMIM_en=[]
#geneSymbol=[]
#inheritance=[]

#i=0
#for i in range(len(OMIM_new['Phenotype MIM number'])):
#    des_en= OMIM_new['Phenotype'][i]+'(OMIM:'+ str(OMIM_new['Phenotype MIM number'][i])+', '+str(OMIM_new['Inheritance'][i]) + ')'
#    des_ch= OMIM_new['Translation_Phenotype'][i] +'(OMIM:'+ str(OMIM_new['Phenotype MIM number'][i]) +', '+str(OMIM_new['Inheritance'][i])+ ')'
#    symbol= OMIM_new['Gene/Locus'][i]
#    #inher = OMIM_new['Inheritance'][i]
#    OMIM_en.append(des_en)
#    OMIM_ch.append(des_ch)
#    geneSymbol.append(symbol)
#    #inheritance.append(inher)
#new_OMIM={'Gene':geneSymbol,'OMIM_en':OMIM_en,'OMIM_ch':OMIM_ch}
#OMIM_trans=pd.DataFrame(new_OMIM)

# %%
#geneSymbol_uniq=list(set(geneSymbol))

# %%
## generate the database format 
#dict={}
#description_save_en=[]
#description_save_ch=[]
#geneName=[]
#for i in range(len(geneSymbol_uniq)):
#    my_tmp=''
#    my_tmp_ch=''
#    for k in range(len(geneSymbol)):
#        if OMIM_trans['Gene'][k]==geneSymbol_uniq[i] :
#            my_tmp+=OMIM_trans['OMIM_en'][k]+';'
#            my_tmp_ch+=OMIM_trans['OMIM_ch'][k]+';'
#    description_save_en.append(my_tmp[:-1])
#    description_save_ch.append(my_tmp_ch[:-1])
#    geneName.append(geneSymbol_uniq[i])

# %%
#final_dict={'Gene':geneName,'OMIM_en':description_save_en,'OMIM_ch':description_save_ch}

# %%
#OMIM_merge=pd.DataFrame(final_dict)

# %%
#OMIM_merge.to_csv('OMIM_08_26.csv',index=False)

# %%
## loading the file 
HPO_old=pd.read_csv('DBHPO.csv')
HPO_Gene=pd.read_csv('HPO_relates_Disease/HPO_relates_Disease.csv')
HPO_ch=pd.read_csv('HPO_relates_Disease/HPO_datasets_20220722.csv')
HPO_phen2gene=pd.read_csv('phenotype_to_genes.txt',sep='\t', header=None)
HPO_gene2phen=pd.read_csv('genes_to_phenotype.txt',sep='\t', header=None)
CHPO_raw=pd.read_csv('CHPO.csv',dtype=str)
omim=pd.read_csv('08_26_all_omim_phenotype_translation.csv')
omim_chinesed=pd.read_csv('OMIM_08_26.csv')

# %%
## change the raw_data 
HPO_phen2gene.keys()
col_name={0:'entrez_id',1:'Gene_symbol',2:'HPO_id',3:'HPO_description'}
HPO_phen2gene.rename(columns={0:'HPO_id',1:'HPO_description',2:'entrez_id',3:'Gene_symbol'},inplace=True)
HPO_gene2phen.rename(columns=col_name,inplace=True)

# %%
hpo_gene_phen2gen=list(set(HPO_phen2gene['Gene_symbol']))
hpo_gene_nc=list(set(HPO_Gene['entrezGeneSymbol']))
hpo_gene_ge2ph=list(set(HPO_gene2phen['Gene_symbol']))
hpo_gene_old_db=list(set(HPO_old['id']))
omim_genn=list(set(omim['Gene/Locus']))

# %%
hpo_id_phen2gen=list(set(HPO_phen2gene['HPO_id']))
hpo_id_nc=list(set(HPO_Gene['HPO_id']))
hpo_id_ge2ph=list(set(HPO_gene2phen['HPO_id']))

# %%
hpo_id_judge=[]
omim_id_jude=[]
hpo_gene_phVgen_ju=[]

# %%
for i in range(len(hpo_id_phen2gen)):
    if hpo_id_phen2gen[i] in hpo_gene_ge2ph:
        str='T'
    else:
        str='F'
    hpo_id_judge.append(str)
    if hpo_id_phen2gen[i] in omim_genn:
        str='T'
    else:
        str='F'
    omim_id_jude.append(str)
for i in range(len(hpo_gene_ge2ph)):
    if hpo_gene_ge2ph[i] in hpo_gene_phen2gen:
        str='T'
    else:
        str='F'
    hpo_gene_phVgen_ju.append(str)

# %%
Counts={'hpo_gene':hpo_gene_phVgen_ju}
Counts=pd.DataFrame(Counts)

# %%
gene_counts=pd.value_counts(Counts['hpo_gene'])

# %%
#pd.value_counts(CHPO_raw['HPO_name'])
CHPO_raw
# Out:
#                                                   def_en  \
# 0                                                    NaN
# 1      Deviation from the norm of height with respect...
# 2      Multicystic dysplasia of the kidney is charact...
# 3      The pattern in which a particular genetic trai...
# 4      A mode of inheritance that is observed for tra...
# 5      A mode of inheritance that is observed for tra...
# 6      An abnormality of the `female internal genital...
# 7      `Dysfunction` (PATO:0001641) of the `urinary b...
# 8              Repeated infections of the urinary tract.
# 9      An inability to completely empty the `urinary ...
# 10     Urge incontinence is the strong, sudden need t...
# 11         Underdevelopment of the `uterus` (FMA:17558).
# 12     An abnormality of the `urinary bladder` (FMA:1...
# 13     `Diverticulum` (MPATH:68) (sac or pouch) in th...
# 14     Inability to completely empty the `urinary bla...
# 15     Abnormally increased production of urine durin...
# 16     Difficulty in beginning the process of `urinat...
# 17     Loss of the ability to control the `urinary bl...
# 18                Dilatation of the bladder postnatally.
# 19     An abnormality of the `male internal genitalia...
# 20     Protrusion of the contents of the abdominal ca...
# 21     The presence of `inflammation` (MPATH:212) of ...
# 22                                                 #####
# 23     "Decreased functionality" (PATO:0001624) of th...
# 24     Absence of any measurable level of sperm in hi...
# 25     Absence of one or both testes from the scrotum...
# 26     Wasting (atrophy) of the testicle (the male go...
# 27     The presence of a `gonadoblastoma` (MPATH:315)...
# 28     The presence of `inflammation` (MPATH:212) of ...
# 29     An abnormality of `male external genitalia` (F...
# ...                                                  ...
# 15246              An abnormality of an odontoid tissue.
# 15247             An abnormality of a hyoglossus muscle.
# 15248                    An abnormality of a hyoid bone.
# 15249                   An abnormality of a hypopharynx.
# 15250     An abnormality of an inferior alveolar artery.
# 15251      An abnormality of an inferior alveolar nerve.
# 15252          An abnormality of an artery of lower lip.
# 15253  An abnormality of an inferior oblique extraocu...
# 15254  An abnormality of an inferior rectus extraocul...
# 15255        An abnormality of an inferior thyroid vein.
# 15256          An abnormality of an infraorbital artery.
# 15257          An abnormality of an infra-orbital nerve.
# 15258      An abnormality of an internal carotid artery.
# 15259        An abnormality of an internal jugular vein.
# 15260   An abnormality of an intrinsic muscle of tongue.
# 15261               An abnormality of a lacrimal artery.
# 15262                  An abnormality of a lacrimal sac.
# 15263       An abnormality of a lateral crico-arytenoid.
# 15264      An abnormality of a lateral pterygoid muscle.
# 15265  An abnormality of a lateral rectus extra-ocula...
# 15266           An abnormality of a levator anguli oris.
# 15267      An abnormality of a levator labii superioris.
# 15268  An abnormality of a levator palpebrae superioris.
# 15269         An abnormality of a levator veli palatini.
# 15270                An abnormality of a lingual artery.
# 15271                 An abnormality of a lingual nerve.
# 15272                An abnormality of a lingual tonsil.
# 15273     An abnormality of a mandible condylar process.
# 15274     An abnormality of a mandible coronoid process.
# 15275          An abnormality of a mandibular symphysis.
#
#                                                   def_cn      HPO_id  \
# 0                                                    NaN  HP:0000001
# 1                                    身高偏离该年龄性别预期身高的正常范围。  HP:0000002
# 2      多囊性肾发育不良的特点是：肾脏有大小不一的肾囊肿，缺乏正常肾盂肾盏系统。这种状态伴发输尿管或...  HP:0000003
# 3                                                    NaN  HP:0000005
# 4                                                    NaN  HP:0000006
# 5                                                    NaN  HP:0000007
# 6                                             女性内生殖器的异常。  HP:0000008
# 7                                               膀胱的功能异常。  HP:0000009
# 8                                                尿路反复感染。  HP:0000010
# 9                               由于神经系统疾患导致排尿过程中无法完全排空膀胱。  HP:0000011
# 10                                     突然的强烈排尿感导致急迫性尿失禁。  HP:0000012
# 11                                               子宫发育低下。  HP:0000013
# 12                                             发生在膀胱的异常。  HP:0000014
# 13                                             膀胱壁上存在憩室。  HP:0000015
# 14                                        排尿过程中无法完全排空膀胱。  HP:0000016
# 15                                  夜间尿量异常增多导致异乎寻常的频繁排尿。  HP:0000017
# 16                                              排尿开始时不畅。  HP:0000019
# 17                                    膀胱控制能力丧失，导致非自主性排尿。  HP:0000020
# 18                                              出生后膀胱扩张。  HP:0000021
# 19                                            男性内生殖器的异常。  HP:0000022
# 20                                       经由腹股沟的腹腔内容物的突起。  HP:0000023
# 21                                              前列腺出现炎症。  HP:0000024
# 22                                                   NaN  HP:0000025
# 23                                          男性性腺即睾丸功能减退。  HP:0000026
# 24                                            精液中检测不到精子。  HP:0000027
# 25                       阴囊内一侧或双侧睾丸缺如，是由于睾丸未通过腹股沟管下降到阴囊。  HP:0000028
# 26                                睾丸萎缩表现为体积减小和潜在的生育能力丧失。  HP:0000029
# 27                                        睾丸部位形成的性腺母细胞瘤。  HP:0000030
# 28                                             附睾发生的炎症 。  HP:0000031
# 29                                            男性外生殖器的异常。  HP:0000032
# ...                                                  ...         ...
# 15246                                            齿状突组织异常  HP:3000050
# 15247                                            舌骨舌肌异常。  HP:3000051
# 15248                                               舌骨异常  HP:3000052
# 15249                                             下咽部异常。  HP:3000053
# 15250                                           下牙槽动脉异常。  HP:3000054
# 15251        下牙槽神经损伤是下颌智齿拔除术后或下颌骨损伤比较严重的并发症之一，常引起下牙感觉异常。  HP:3000055
# 15252                                            下唇动脉异常。  HP:3000056
# 15253                                           下斜眼外肌异常。  HP:3000057
# 15254                                           下直眼外肌异常。  HP:3000058
# 15255                                          甲状腺下静脉异常。  HP:3000059
# 15256                                            眶下动脉异常。  HP:3000060
# 15257  眶下神经为上颌神经的终支，通过眶下沟、眶下管、出眶下孔至面部，分为数支分布于下睑、鼻翼和上唇...  HP:3000061
# 15258                                            颈内动脉异常。  HP:3000062
# 15259                                            颈内静脉异常。  HP:3000063
# 15260                                            舌固有肌异常。  HP:3000064
# 15261                                            泪腺动脉异常。  HP:3000065
# 15262                                              泪囊异常。  HP:3000066
# 15263                                            环杓侧肌异常。  HP:3000067
# 15264                                             翼外肌异常。  HP:3000068
# 15265                                            眼外直肌异常。  HP:3000069
# 15266                                            口角提肌异常。  HP:3000070
# 15267                                            提上唇肌异常。  HP:3000071
# 15268                                            提上睑肌异常。  HP:3000072
# 15269                                            腭帆提肌异常。  HP:3000073
# 15270                                             舌动脉异常。  HP:3000074
# 15271         舌神经异常是由于舌神经损伤所导致的暂时性或永久性的同侧前2/3的舌体麻木和味觉障碍。  HP:3000075
# 15272                                            舌扁桃体异常。  HP:3000076
# 15273                                            下颌骨髁突异常  HP:3000077
# 15274                                            下颌骨喙突异常  HP:3000078
# 15275                                             下颌联合异常  HP:3000079
#
#                                                 category    HPO_name  \
# 0                                                    NaN         NaN
# 1                               Growth abnormality(生长异常)        身高异常
# 2      Abnormality of the genitourinary system(泌尿生殖系统异常)    多囊性肾发育不良
# 3                              Mode of inheritance(遗传模式)        遗传模式
# 4                              Mode of inheritance(遗传模式)    常染色体显性遗传
# 5                              Mode of inheritance(遗传模式)    常染色体隐性遗传
# 6      Abnormality of the genitourinary system(泌尿生殖系统异常)    女性内生殖器异常
# 7      Abnormality of the genitourinary system(泌尿生殖系统异常)      膀胱功能异常
# 8      Abnormality of the genitourinary system(泌尿生殖系统...     复发性尿路感染
# 9      Abnormality of the genitourinary system(泌尿生殖系统异常)  神经源性膀胱功能障碍
# 10     Abnormality of the genitourinary system(泌尿生殖系统异常)          尿急
# 11     Abnormality of the genitourinary system(泌尿生殖系统异常)      子宫发育不良
# 12     Abnormality of the genitourinary system(泌尿生殖系统异常)        膀胱异常
# 13     Abnormality of the genitourinary system(泌尿生殖系统异常)        膀胱憩室
# 14     Abnormality of the genitourinary system(泌尿生殖系统异常)         尿潴留
# 15     Abnormality of the genitourinary system(泌尿生殖系统异常)         夜尿症
# 16     Abnormality of the genitourinary system(泌尿生殖系统异常)        排尿踌躇
# 17     Abnormality of the genitourinary system(泌尿生殖系统异常)         尿失禁
# 18     Abnormality of the genitourinary system(泌尿生殖系统异常)        巨膀胱症
# 19     Abnormality of the genitourinary system(泌尿生殖系统异常)    男性内生殖器异常
# 20     Abnormality of connective tissue(结缔组织异常)|Abnor...        腹股沟疝
# 21     Abnormality of the genitourinary system(泌尿生殖系统...        前列腺炎
# 22     Abnormality of the genitourinary system(泌尿生殖系统异常)  男性内生殖器功能异常
# 23     Abnormality of the genitourinary system(泌尿生殖系统...   男性性腺功能减退症
# 24     Abnormality of the genitourinary system(泌尿生殖系统异常)         无精症
# 25     Abnormality of the genitourinary system(泌尿生殖系统异常)          隐睾
# 26     Abnormality of the genitourinary system(泌尿生殖系统异常)        睾丸萎缩
# 27     Abnormality of the genitourinary system(泌尿生殖系统...    睾丸性腺母细胞瘤
# 28     Abnormality of the genitourinary system(泌尿生殖系统...         附睾炎
# 29     Abnormality of the genitourinary system(泌尿生殖系统异常)    男性外生殖器异常
# ...                                                  ...         ...
# 15246  Abnormality of the skeletal system(骨骼系统异常)|Abn...     齿状突组织异常
# 15247  Abnormality of head and neck(头部和颈部的异常)|Abnorma...      舌骨舌肌异常
# 15248         Abnormality of the skeletal system(骨骼系统异常)        舌骨异常
# 15249             Abnormality of head and neck(头部和颈部的异常)       下咽部异常
# 15250  Abnormality of head and neck(头部和颈部的异常)|Abnorma...     下牙槽动脉异常
# 15251  Abnormality of head and neck(头部和颈部的异常)|Abnorma...     下牙槽神经异常
# 15252  Abnormality of the cardiovascular system(心血管系统异常)      下唇动脉异常
# 15253  Abnormality of head and neck(头部和颈部的异常)|Abnorma...     下斜眼外肌异常
# 15254  Abnormality of head and neck(头部和颈部的异常)|Abnorma...     下直眼外肌异常
# 15255  Abnormality of the cardiovascular system(心血管系统异常)    甲状腺下静脉异常
# 15256  Abnormality of the cardiovascular system(心血管系统异常)      眶下动脉异常
# 15257  Abnormality of head and neck(头部和颈部的异常)|Abnorma...      眶下神经异常
# 15258  Abnormality of head and neck(头部和颈部的异常)|Abnorma...      颈内动脉异常
# 15259  Abnormality of head and neck(头部和颈部的异常)|Abnorma...      颈内静脉异常
# 15260  Abnormality of head and neck(头部和颈部的异常)|Abnorma...      舌固有肌异常
# 15261  Abnormality of head and neck(头部和颈部的异常)|Abnorma...      泪腺动脉异常
# 15262             Abnormality of head and neck(头部和颈部的异常)        泪囊异常
# 15263  Abnormality of head and neck(头部和颈部的异常)|Abnorma...      环杓侧肌异常
# 15264  Abnormality of head and neck(头部和颈部的异常)|Abnorma...       翼外肌异常
# 15265  Abnormality of head and neck(头部和颈部的异常)|Abnorma...      眼外直肌异常
# 15266  Abnormality of head and neck(头部和颈部的异常)|Abnorma...      口角提肌异常
# 15267  Abnormality of head and neck(头部和颈部的异常)|Abnorma...      提上唇肌异常
# 15268  Abnormality of head and neck(头部和颈部的异常)|Abnorma...      提上睑肌异常
# 15269  Abnormality of head and neck(头部和颈部的异常)|Abnorma...      腭帆提肌异常
# 15270  Abnormality of head and neck(头部和颈部的异常)|Abnorma...       舌动脉异常
# 15271  Abnormality of head and neck(头部和颈部的异常)|Abnorma...       舌神经异常
# 15272  Abnormality of head and neck(头部和颈部的异常)|Abnorma...      舌扁桃体异常
# 15273  Abnormality of head and neck(头部和颈部的异常)|Abnorma...     下颌骨髁突异常
# 15274  Abnormality of head and neck(头部和颈部的异常)|Abnorma...     下颌骨喙突异常
# 15275         Abnormality of the skeletal system(骨骼系统异常)      下颌联合异常
#
#                                                HPO_cname
# 0                                                    ALL
# 1                             Abnormality of body height
# 2                           Multicystic kidney dysplasia
# 3                                    Mode of inheritance
# 4                         Autosomal dominant inheritance
# 5                        Autosomal recessive inheritance
# 6               Abnormality of female internal genitalia
# 7                  Functional abnormality of the bladder
# 8                     Recurrent urinary tract infections
# 9                                     Neurogenic bladder
# 10                                       Urinary urgency
# 11                              Hypoplasia of the uterus
# 12                            Abnormality of the bladder
# 13                                  Bladder diverticulum
# 14                                     Urinary retention
# 15                                              Nocturia
# 16                                     Urinary hesitancy
# 17                                  Urinary incontinence
# 18                                            Megacystis
# 19                Abnormality of male internal genitalia
# 20                                       Inguinal hernia
# 21                                           Prostatitis
# 22     Functional abnormality of male internal genitalia
# 23                                     Male hypogonadism
# 24                                           Azoospermia
# 25                                        Cryptorchidism
# 26                                    Testicular atrophy
# 27                             Testicular gonadoblastoma
# 28                                          Epididymitis
# 29                Abnormality of male external genitalia
# ...                                                  ...
# 15246                     Abnormality of odontoid tissue
# 15247                   Abnormality of hyoglossus muscle
# 15248                          Abnormality of hyoid bone
# 15249                         Abnormality of hypopharynx
# 15250            Abnormality of inferior alveolar artery
# 15251             Abnormality of inferior alveolar nerve
# 15252                 Abnormality of artery of lower lip
# 15253  Abnormality of inferior oblique extraocular mu...
# 15254  Abnormality of inferior rectus extraocular muscle
# 15255               Abnormality of inferior thyroid vein
# 15256                 Abnormality of infraorbital artery
# 15257                 Abnormality of infra-orbital nerve
# 15258             Abnormality of internal carotid artery
# 15259               Abnormality of internal jugular vein
# 15260          Abnormality of intrinsic muscle of tongue
# 15261                     Abnormality of lacrimal artery
# 15262                        Abnormality of lacrimal sac
# 15263             Abnormality of lateral crico-arytenoid
# 15264            Abnormality of lateral pterygoid muscle
# 15265  Abnormality of lateral rectus extra-ocular muscle
# 15266                 Abnormality of levator anguli oris
# 15267            Abnormality of levator labii superioris
# 15268        Abnormality of levator palpebrae superioris
# 15269        Abnormality of levator veli palatini muscle
# 15270                      Abnormality of lingual artery
# 15271                       Abnormality of lingual nerve
# 15272                      Abnormality of lingual tonsil
# 15273           Abnormality of mandible condylar process
# 15274           Abnormality of mandible coronoid process
# 15275                Abnormality of mandibular symphysis
#
# [15276 rows x 6 columns]

# %%
print(CHPO_raw.dtypes)
CHPO_raw['HPO_name']= CHPO_raw['HPO_name'].astype(np.str)
# Out:
# def_en       object
# def_cn       object
# HPO_id       object
# category     object
# HPO_name     object
# HPO_cname    object
# dtype: object

# %%
print(CHPO_raw.dtypes)
# Out:
# def_en       object
# def_cn       object
# HPO_id       object
# category     object
# HPO_name     object
# HPO_cname    object
# dtype: object

# %%
for i in hpo_gene_ge2ph:
    HPO_description=[]
    HPO_description_ch=[]
    HPO_description_merge=[]
    HPO_description_merge_ch=[]
    gene_symbol=[]
    for k in range(len(HPO_phen2gene)):
        if i == HPO_phen2gene['Gene_symbol'][k]:
            str_tmp_ph2gen_en=HPO_phen2gene['HPO_description'][k]+ ' (' + HPO_phen2gene['HPO_id'][k] + ')'
            for kk in range(len(CHPO_raw)):
                if HPO_phen2gene['HPO_id'][k] == CHPO_raw['HPO_id'][kk]:
                    str_tmp_ph2gen_ch=  CHPO_raw['HPO_name'][kk] + '(' + HPO_phen2gene['HPO_id'][k] + ')'
                    HPO_description_ch.append(str_tmp_ph2gen_ch)
            HPO_description.append(str_tmp_ph2gen_en)
    for m in range(len(HPO_gene2phen)):
        if i == HPO_gene2phen['Gene_symbol'][m]:
            str_tmp_ge2ph_en= HPO_gene2phen['HPO_description'][m]+ ' (' + HPO_gene2phen['HPO_id'][m] + ')'
            for mm in range(len(CHPO_raw)):
                if HPO_gene2phen['HPO_id'][m] == CHPO_raw['HPO_id'][mm]:
                    str_tmp_ge2ph_ch= CHPO_raw['HPO_name'][mm] + '(' + HPO_gene2phen['HPO_id'][m] + ')'
                    HPO_description_ch.append(str_tmp_ge2ph_ch)
            HPO_description.append(str_tmp_ge2ph_en)
    HPO_description_uniq=list(set(HPO_description))
    HPO_description_ch_uniq=list(set(HPO_description_ch))
    #print(HPO_description_uniq)
    tmp=''
    tmp_2=''
    for x in HPO_description_uniq:
        tmp += x + ';'
    str_tmp=tmp[:-1]
    for z in HPO_description_ch_uniq:
        tmp_2 += z + ';'
    str_tmp_ch= tmp_2[:-1]
    #print(str_tmp)
    HPO_description_merge.append(str_tmp)
    HPO_description_merge_ch.append(str_tmp_ch)
    gene_symbol.append(i)
New_HPO_data={'Gene_symbo':gene_symbol,'HPO_en':HPO_description_merge,'HPO_ch':HPO_description_merge_ch}
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/2h/rtg6hrd97yl__yfcsv92n6240000gn/T/ipykernel_42186/3223930292.py in <module>
#       9             str_tmp_ph2gen_en=HPO_phen2gene['HPO_description'][k]+ ' (' + HPO_phen2gene['HPO_id'][k] + ')'
#      10             for kk in range(len(CHPO_raw)):
# ---> 11                 if HPO_phen2gene['HPO_id'][k] == CHPO_raw['HPO_id'][kk]:
#      12                     str_tmp_ph2gen_ch=  CHPO_raw['HPO_name'][kk] + '(' + HPO_phen2gene['HPO_id'][k] + ')'
#      13                     HPO_description_ch.append(str_tmp_ph2gen_ch)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4340         return result.argsort(*args, **kwargs)
#    4341
# -> 4342     def get_value(self, series, key):
#    4343         """
#    4344         Fast lookup of value from 1-dimensional ndarray. Only use this if you
#
# KeyboardInterrupt:

# %%
### chinesed HPO database 
HPO_chinese_description=[]
HPO_raw_description=[]

# %%
a=pd.read_csv('OMIM_08_26.csv')

# %%
a
# Out:
#           Gene                                            OMIM_en  \
# 0         FIG4  Amyotrophic lateral sclerosis 11(OMIM:612577, ...
# 1      PLA2G2A  {?Colorectal cancer, susceptibility to}(OMIM:1...
# 2        SMC1A  Cornelia de Lange syndrome 2(OMIM:300590, XLD)...
# 3         STK4  T-cell immunodeficiency, recurrent infections,...
# 4         DEF6  Immunodeficiency 87 and autoimmunity(OMIM:6195...
# 5        ITGB3  Glanzmann thrombasthenia 2(OMIM:619267, nan);B...
# 6         GAS8   Ciliary dyskinesia, primary, 33(OMIM:616726, AR)
# 7         LHX3  Pituitary hormone deficiency, combined, 3(OMIM...
# 8       CRYBB3                   Cataract 22(OMIM:609741, AD, AR)
# 9      MCOPCB4  Microphthalmia, isolated, with coloboma 4(OMIM...
# 10       ITM2B  Dementia, familial Danish(OMIM:117300, AD);Dem...
# 11    RAB3GAP1  Warburg micro syndrome 1(OMIM:600118, AR);Mart...
# 12        ICR1  Beckwith-Wiedemann syndrome(OMIM:130650, AD);S...
# 13      CYP2D6  {Debrisoquine sensitivity}(OMIM:608902, AR);{C...
# 14         EA3           Episodic ataxia, type 3(OMIM:606554, AD)
# 15        G6PD  Hemolytic anemia, G6PD deficient (favism)(OMIM...
# 16       MPDU1  Congenital disorder of glycosylation, type If(...
# 17         MPZ  Charcot-Marie-Tooth disease, type 1B(OMIM:1182...
# 18       SYNE1  Spinocerebellar ataxia, autosomal recessive 8(...
# 19     SNORA31  {Encephalopathy, acute, infection-induced (her...
# 20       RAD51  {Breast cancer, susceptibility to}(OMIM:114480...
# 21     CYP4F22  Ichthyosis, congenital, autosomal recessive 5(...
# 22       CDKL5  Developmental and epileptic encephalopathy 2(O...
# 23       GNA11  Hypocalciuric hypercalcemia, type II(OMIM:1459...
# 24      MAP2K1  Melorheostosis, isolated, somatic mosaic(OMIM:...
# 25        RNF6    Esophageal carcinoma, somatic(OMIM:133239, nan)
# 26      TSPYL1  Sudden infant death with dysgenesis of the tes...
# 27       NSDHL  CK syndrome(OMIM:300831, XLR);CHILD syndrome(O...
# 28        HCN4  Sick sinus syndrome 2(OMIM:163800, AD);Brugada...
# 29         DCN  Corneal dystrophy, congenital stromal(OMIM:610...
# ...        ...                                                ...
# 4701      DSC2  Arrhythmogenic right ventricular dysplasia 11(...
# 4702      EDN3  Waardenburg syndrome, type 4B(OMIM:613265, AD,...
# 4703    PPP3CA  Developmental and epileptic encephalopathy 91(...
# 4704     MARS2  Spastic ataxia 3, autosomal recessive(OMIM:611...
# 4705    CARD14  Pityriasis rubra pilaris(OMIM:173200, AD);Psor...
# 4706      MUC7      {Asthma, protection against}(OMIM:600807, AD)
# 4707       CFB  {Hemolytic uremic syndrome, atypical, suscepti...
# 4708   SLC52A3  ?Fazio-Londe disease(OMIM:211500, AR);Brown-Vi...
# 4709       GHR  {Hypercholesterolemia, familial, modifier of}(...
# 4710     MMP19     Cavitary optic disc anomalies(OMIM:611543, AD)
# 4711      FDXR  Auditory neuropathy and optic atrophy(OMIM:617...
# 4712    MBTPS2  ?Olmsted syndrome, X-linked(OMIM:300918, XLR);...
# 4713      RAX2  Cone-rod dystrophy 11(OMIM:610381, AD);?Macula...
# 4714     TULP3  Hepatorenocardiac degenerative fibrosis(OMIM:6...
# 4715      APTX  Ataxia, early-onset, with oculomotor apraxia a...
# 4716     RBCK1  Polyglucosan body myopathy 1 with or without i...
# 4717   TMEM138               Joubert syndrome 16(OMIM:614465, AR)
# 4718     AP2M1  Intellectual developmental disorder 60 with se...
# 4719      PPCS       Cardiomyopathy, dilated, 2C(OMIM:618189, AR)
# 4720      VSX1  Keratoconus 1(OMIM:148300, AD);?Craniofacial a...
# 4721     ACADM  Acyl-CoA dehydrogenase, medium chain, deficien...
# 4722     DNMT1  Cerebellar ataxia, deafness, and narcolepsy, a...
# 4723       MIF  {Rheumatoid arthritis, systemic juvenile, susc...
# 4724    PNPLA1  Ichthyosis, congenital, autosomal recessive 10...
# 4725    STING1  STING-associated vasculopathy, infantile-onset...
# 4726    SHANK3  Phelan-McDermid syndrome(OMIM:606232, AD);{Sch...
# 4727      RP24          Retinitis pigmentosa 24(OMIM:300155, nan)
# 4728      MBL2  {Chronic infections, due to MBL deficiency}(OM...
# 4729     PLVAP  Diarrhea 10, protein-losing enteropathy type(O...
# 4730     IGLL1              Agammaglobulinemia 2(OMIM:613500, AR)
#
#                                                 OMIM_ch
# 0     肌萎缩侧索硬化症 11(OMIM:612577, AD);尤尼斯-瓦隆综合征(OMIM:21...
# 1                      {?大肠癌，易感性}(OMIM:114500, AD, SMu)
# 2     Cornelia de Lange 综合征 2(OMIM:300590, XLD);发育性和...
# 3              T细胞免疫缺陷、反复感染、自身免疫和心脏畸形(OMIM:614868, nan)
# 4                        免疫缺陷 87 和自身免疫(OMIM:619573, AR)
# 5     Glanzmann 血小板无力症 2(OMIM:619267, nan);出血性疾病，血小板...
# 6                        纤毛运动障碍，原发性，33(OMIM:616726, AR)
# 7                          垂体激素缺乏，联合，3(OMIM:221750, AR)
# 8                           白内障 22(OMIM:609741, AD, AR)
# 9                       小眼炎，孤立的，伴有缺损 4(OMIM:251505, AR)
# 10    痴呆症，家族性丹麦人(OMIM:117300, AD);痴呆症，家族性英国人(OMIM:17...
# 11    Warburg 微综合征 1(OMIM:600118, AR);Martsolf 综合征 2...
# 12    Beckwith-Wiedemann 综合征(OMIM:130650, AD);Silver...
# 13    {Debrisoquine 敏感性}(OMIM:608902, AR);{可待因敏感性}(O...
# 14                         发作性共济失调，3 型(OMIM:606554, AD)
# 15    溶血性贫血，G6PD 缺乏症（favism）(OMIM:300908, XLD);{G6PD...
# 16                        先天性糖基化障碍，If型(OMIM:609180, AR)
# 17    Charcot-Marie-Tooth 病，1B 型(OMIM:118200, AD);德杰...
# 18    脊髓小脑性共济失调，常染色体隐性遗传 8(OMIM:610743, AR);Emery-Dr...
# 19          {脑病，急性，感染诱发（疱疹特异性），易感性，10}(OMIM:619396, AD)
# 20    {乳腺癌，易感性}(OMIM:114480, AD, SMu);镜像动作 2(OMIM:61...
# 21                  鱼鳞病，先天性，常染色体隐性遗传 5(OMIM:604777, AR)
# 22                        发育性和癫痫性脑病 2(OMIM:300672, XLD)
# 23    低尿钙高钙血症，II型(OMIM:145981, AD);低钙血症，常染色体显性遗传 2(O...
# 24    Melorheostosis，孤立的，体细胞镶嵌(OMIM:155950, nan);心面皮...
# 25                            食道癌，体细胞(OMIM:133239, nan)
# 26                     睾丸发育不全综合征导致婴儿猝死(OMIM:608800, AR)
# 27      CK综合征(OMIM:300831, XLR);儿童综合征(OMIM:308050, XLD)
# 28    病态窦房结综合征 2(OMIM:163800, AD);Brugada 综合征 8(OMIM...
# 29                        角膜营养不良，先天性基质(OMIM:610048, AD)
# ...                                                 ...
# 4701  致心律失常性右心室发育不良 11(OMIM:610476, AD, AR);致心律失常性右心...
# 4702  Waardenburg 综合征，4B 型(OMIM:613265, AD, AR);{先天性...
# 4703  发育性和癫痫性脑病 91(OMIM:617711, AD);关节弯曲、腭裂、颅缝早闭和智力发...
# 4704  痉挛性共济失调 3，常染色体隐性遗传(OMIM:611390, AR);?联合氧化磷酸化缺乏...
# 4705      毛发红糠疹(OMIM:173200, AD);牛皮癣 2(OMIM:602723, AD)
# 4706                           {哮喘，预防}(OMIM:600807, AD)
# 4707  {溶血性尿毒症综合征，非典型，易感性，4}(OMIM:612924, AD);{黄斑变性，年...
# 4708  ? Fazio-Londe 病(OMIM:211500, AR);Brown-Vialett...
# 4709  {高胆固醇血症，家族性，修饰符}(OMIM:143890, AD, AR);拉伦侏儒症(OM...
# 4710                            空洞视盘异常(OMIM:611543, AD)
# 4711                        听神经病和视神经萎缩(OMIM:617717, AR)
# 4712  ?Olmsted 综合征，X 连锁(OMIM:300918, XLR);成骨不全症，XIX ...
# 4713  锥杆营养不良 11(OMIM:610381, AD);?黄斑变性，年龄相关，6(OMIM:6...
# 4714                         肝心肾退行性纤维化(OMIM:619902, AR)
# 4715           早发性共济失调，伴有动眼神经失用和低白蛋白血症(OMIM:208920, AR)
# 4716                  多糖体肌病 1 伴或不伴免疫缺陷(OMIM:615895, AR)
# 4717                    Joubert 综合征 16(OMIM:614465, AR)
# 4718                  智力发育障碍 60 伴有癫痫发作(OMIM:618587, AD)
# 4719                         扩张型心肌病，2C(OMIM:618189, AR)
# 4720  圆锥角膜 1(OMIM:148300, AD);? 颅面畸形和眼前节发育不全综合征(OMIM...
# 4721                    酰基辅酶A脱氢酶，中链，缺乏(OMIM:201450, AR)
# 4722  小脑性共济失调、耳聋和发作性睡病，常染色体显性遗传(OMIM:604121, AD);神经病...
# 4723             {类风湿性关节炎，全身性青少年，易感性}(OMIM:604302, nan)
# 4724               鱼鳞病，先天性，常染色体隐性遗传 10(OMIM:615024, AR)
# 4725                STING 相关血管病变，婴儿期发病(OMIM:615934, AD)
# 4726  Phelan-McDermid 综合征(OMIM:606232, AD);{精神分裂症 15...
# 4727                       色素性视网膜炎 24(OMIM:300155, nan)
# 4728                  {慢性感染，由于 MBL 缺乏}(OMIM:614372, AD)
# 4729                   腹泻 10，蛋白质丢失性肠病型(OMIM:618183, AR)
# 4730                        无丙种球蛋白血症 2(OMIM:613500, AR)
#
# [4731 rows x 3 columns]
